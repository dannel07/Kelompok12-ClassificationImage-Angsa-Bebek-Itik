# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers

# %%
data_train_path = r'D:\certan\dataset'
data_test_path = r'D:\certan\dataset'
data_val_path = r'D:\certan\dataset'

# %%
img_width = 180
img_height =180

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle=True,
    image_size=(img_width, img_height),
    batch_size=32,
    validation_split=False)
# Out:
# Found 1467 files belonging to 3 classes.

# %%
data_val = tf.keras.utils.image_dataset_from_directory(data_val_path,
                                                       image_size=(img_height,img_width),
                                                       batch_size=32,
                                                        shuffle=False,
                                                       validation_split=False)
# Out:
# Found 1467 files belonging to 3 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
data_test_path,
    image_size=(img_height,img_width),
    shuffle=True,
    batch_size=32,
    validation_split=False
)
# Out:
# Found 1467 files belonging to 3 classes.

# %%
data_unggas = data_train.class_names

# %%
data_unggas
# Out:
# ['Angsa', 'Bebek', 'Itik']

# %%
plt.figure(figsize=(10,10))
for image, labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_unggas[labels[i]])
        plt.axis('off')

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras import Sequential, layers

# Perbaikan model dengan augmentasi
model = Sequential([
    # Augmentasi data
    layers.RandomFlip("horizontal", input_shape=(180, 180, 3)),  # Membalik gambar secara horizontal
    layers.RandomRotation(0.9),  # Rotasi acak hingga 10%
    layers.RandomZoom(0.1),  # Zoom in/out hingga 10%
    layers.RandomContrast(0.2),  # Mengubah kontras gambar secara acak
    layers.RandomBrightness(factor=0.2),  # Menambah/mengurangi kecerahan secara acak
    layers.RandomTranslation(height_factor=0.2, width_factor=0.2),  # Translasi gambar secara horizontal/vertikal hingga 20%
    layers.GaussianNoise(0.1),
    
    # Normalisasi data
    layers.Rescaling(1./255),  
    
    # Convolutional layers
    layers.Conv2D(16, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(128, 3, padding='same', activation='relu'),
    layers.MaxPooling2D(),
    
    
    # Fully connected layers
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128, activation='relu'),
    layers.Dense(len(data_unggas), activation='softmax')  # Output untuk klasifikasi
])
# Out:
# C:\Users\TUF\anaconda3\Lib\site-packages\keras\src\layers\preprocessing\tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)             │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_rotation (RandomRotation)     │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_zoom (RandomZoom)             │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_contrast (RandomContrast)     │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_brightness (RandomBrightness) │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation                   │ (None, 180, 180, 3)         │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise (GaussianNoise)       │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 22, 22, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       1,982,592 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,080,419 (7.94 MB)
#  Trainable params: 2,080,419 (7.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=['accuracy'])

# %%
epochs_size = 100
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/100
# C:\Users\TUF\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:635: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 34s 536ms/step - accuracy: 0.3557 - loss: 1.1261 - val_accuracy: 0.4990 - val_loss: 0.9958
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 519ms/step - accuracy: 0.5114 - loss: 0.9828 - val_accuracy: 0.5760 - val_loss: 0.9352
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 516ms/step - accuracy: 0.6132 - loss: 0.8578 - val_accuracy: 0.6026 - val_loss: 0.9234
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 20s 410ms/step - accuracy: 0.6273 - loss: 0.8282 - val_accuracy: 0.6796 - val_loss: 0.7276
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.6282 - loss: 0.7944 - val_accuracy: 0.7130 - val_loss: 0.6749
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - accuracy: 0.6630 - loss: 0.7699 - val_accuracy: 0.6380 - val_loss: 0.7822
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 19s 412ms/step - accuracy: 0.6617 - loss: 0.7359 - val_accuracy: 0.7301 - val_loss: 0.6443
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 355ms/step - accuracy: 0.6805 - loss: 0.7222 - val_accuracy: 0.6953 - val_loss: 0.6684
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.6299 - loss: 0.8263 - val_accuracy: 0.7437 - val_loss: 0.6080
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.6705 - loss: 0.7366 - val_accuracy: 0.5542 - val_loss: 1.0145
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.6632 - loss: 0.7853 - val_accuracy: 0.6224 - val_loss: 0.7959
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.6748 - loss: 0.7343 - val_accuracy: 0.6973 - val_loss: 0.7052
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.6627 - loss: 0.7440 - val_accuracy: 0.7498 - val_loss: 0.5972
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.6932 - loss: 0.7199 - val_accuracy: 0.7328 - val_loss: 0.6036
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.7118 - loss: 0.7070 - val_accuracy: 0.6694 - val_loss: 0.7166
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.7018 - loss: 0.6746 - val_accuracy: 0.7253 - val_loss: 0.6549
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - accuracy: 0.7071 - loss: 0.6789 - val_accuracy: 0.7205 - val_loss: 0.6529
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 316ms/step - accuracy: 0.7026 - loss: 0.6729 - val_accuracy: 0.7662 - val_loss: 0.5593
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.7042 - loss: 0.6860 - val_accuracy: 0.7328 - val_loss: 0.6152
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.7120 - loss: 0.6504 - val_accuracy: 0.7587 - val_loss: 0.5738
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.7265 - loss: 0.6428 - val_accuracy: 0.7519 - val_loss: 0.5594
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.7303 - loss: 0.6301 - val_accuracy: 0.7730 - val_loss: 0.5502
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.7347 - loss: 0.6388 - val_accuracy: 0.7607 - val_loss: 0.5377
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 322ms/step - accuracy: 0.7383 - loss: 0.6105 - val_accuracy: 0.7866 - val_loss: 0.5215
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 303ms/step - accuracy: 0.7522 - loss: 0.6059 - val_accuracy: 0.7648 - val_loss: 0.5644
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 312ms/step - accuracy: 0.7479 - loss: 0.6249 - val_accuracy: 0.7785 - val_loss: 0.5363
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 309ms/step - accuracy: 0.7404 - loss: 0.5917 - val_accuracy: 0.7778 - val_loss: 0.5428
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.7419 - loss: 0.6348 - val_accuracy: 0.7307 - val_loss: 0.6237
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.7792 - loss: 0.5738 - val_accuracy: 0.7478 - val_loss: 0.5761
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 307ms/step - accuracy: 0.7526 - loss: 0.5704 - val_accuracy: 0.7880 - val_loss: 0.5045
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.7659 - loss: 0.5866 - val_accuracy: 0.7703 - val_loss: 0.5341
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.7195 - loss: 0.6172 - val_accuracy: 0.7900 - val_loss: 0.4939
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.7505 - loss: 0.6027 - val_accuracy: 0.7710 - val_loss: 0.5256
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 0.7583 - loss: 0.5830 - val_accuracy: 0.7948 - val_loss: 0.4797
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.7416 - loss: 0.5912 - val_accuracy: 0.7825 - val_loss: 0.5011
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.7607 - loss: 0.5784 - val_accuracy: 0.7505 - val_loss: 0.6117
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 299ms/step - accuracy: 0.7716 - loss: 0.5470 - val_accuracy: 0.7566 - val_loss: 0.6061
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.7459 - loss: 0.5712 - val_accuracy: 0.7982 - val_loss: 0.4703
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.7779 - loss: 0.5579 - val_accuracy: 0.8023 - val_loss: 0.4731
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - accuracy: 0.7440 - loss: 0.6002 - val_accuracy: 0.7532 - val_loss: 0.5646
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 317ms/step - accuracy: 0.7642 - loss: 0.5326 - val_accuracy: 0.8044 - val_loss: 0.4575
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 17s 364ms/step - accuracy: 0.7660 - loss: 0.5447 - val_accuracy: 0.7819 - val_loss: 0.5054
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 453ms/step - accuracy: 0.7683 - loss: 0.5527 - val_accuracy: 0.7580 - val_loss: 0.5490
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 461ms/step - accuracy: 0.7785 - loss: 0.5008 - val_accuracy: 0.8078 - val_loss: 0.4532
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 501ms/step - accuracy: 0.7763 - loss: 0.5298 - val_accuracy: 0.7989 - val_loss: 0.4672
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 492ms/step - accuracy: 0.7721 - loss: 0.5187 - val_accuracy: 0.8125 - val_loss: 0.4746
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 511ms/step - accuracy: 0.7682 - loss: 0.5499 - val_accuracy: 0.7825 - val_loss: 0.4963
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 471ms/step - accuracy: 0.7453 - loss: 0.5749 - val_accuracy: 0.7587 - val_loss: 0.5348
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 456ms/step - accuracy: 0.7461 - loss: 0.5689 - val_accuracy: 0.8187 - val_loss: 0.4380
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 452ms/step - accuracy: 0.7537 - loss: 0.5650 - val_accuracy: 0.8057 - val_loss: 0.4488
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 376ms/step - accuracy: 0.7774 - loss: 0.5373 - val_accuracy: 0.7996 - val_loss: 0.4990
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 305ms/step - accuracy: 0.7735 - loss: 0.5424 - val_accuracy: 0.8078 - val_loss: 0.4496
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.7836 - loss: 0.5038 - val_accuracy: 0.8166 - val_loss: 0.4406
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 313ms/step - accuracy: 0.7923 - loss: 0.5181 - val_accuracy: 0.8098 - val_loss: 0.4487
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 307ms/step - accuracy: 0.7941 - loss: 0.5033 - val_accuracy: 0.8003 - val_loss: 0.4485
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 306ms/step - accuracy: 0.7779 - loss: 0.5112 - val_accuracy: 0.8275 - val_loss: 0.4088
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.7941 - loss: 0.5031 - val_accuracy: 0.8050 - val_loss: 0.4783
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 308ms/step - accuracy: 0.7900 - loss: 0.4968 - val_accuracy: 0.8146 - val_loss: 0.4523
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.7822 - loss: 0.5149 - val_accuracy: 0.8200 - val_loss: 0.4487
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.7804 - loss: 0.4961 - val_accuracy: 0.8146 - val_loss: 0.4473
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - accuracy: 0.7847 - loss: 0.4915 - val_accuracy: 0.7689 - val_loss: 0.5485
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.7709 - loss: 0.5247 - val_accuracy: 0.7819 - val_loss: 0.4967
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - accuracy: 0.7812 - loss: 0.5201 - val_accuracy: 0.8207 - val_loss: 0.4059
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 312ms/step - accuracy: 0.7862 - loss: 0.4704 - val_accuracy: 0.8153 - val_loss: 0.4261
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 345ms/step - accuracy: 0.7887 - loss: 0.5071 - val_accuracy: 0.8064 - val_loss: 0.4487
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.7965 - loss: 0.5152 - val_accuracy: 0.8371 - val_loss: 0.3910
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.7889 - loss: 0.4861 - val_accuracy: 0.8207 - val_loss: 0.4171
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 309ms/step - accuracy: 0.7886 - loss: 0.4882 - val_accuracy: 0.8391 - val_loss: 0.3800
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.7983 - loss: 0.4730 - val_accuracy: 0.8350 - val_loss: 0.3771
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.7743 - loss: 0.5108 - val_accuracy: 0.8378 - val_loss: 0.3991
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.7771 - loss: 0.5037 - val_accuracy: 0.8119 - val_loss: 0.4325
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.8087 - loss: 0.4416 - val_accuracy: 0.8357 - val_loss: 0.4055
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.7983 - loss: 0.4711 - val_accuracy: 0.8384 - val_loss: 0.3964
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.8069 - loss: 0.4437 - val_accuracy: 0.8296 - val_loss: 0.3893
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 315ms/step - accuracy: 0.8068 - loss: 0.4438 - val_accuracy: 0.8425 - val_loss: 0.3669
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.8041 - loss: 0.4553 - val_accuracy: 0.8453 - val_loss: 0.3713
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.8150 - loss: 0.4540 - val_accuracy: 0.8296 - val_loss: 0.3937
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.7840 - loss: 0.4798 - val_accuracy: 0.8125 - val_loss: 0.4252
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.8117 - loss: 0.4590 - val_accuracy: 0.8330 - val_loss: 0.3826
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.8006 - loss: 0.4682 - val_accuracy: 0.8316 - val_loss: 0.3913
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.7957 - loss: 0.4885 - val_accuracy: 0.8146 - val_loss: 0.4263
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.8110 - loss: 0.4301 - val_accuracy: 0.8616 - val_loss: 0.3430
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.8127 - loss: 0.4310 - val_accuracy: 0.8453 - val_loss: 0.3854
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8191 - loss: 0.4222 - val_accuracy: 0.8296 - val_loss: 0.3999
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.7974 - loss: 0.4860 - val_accuracy: 0.8528 - val_loss: 0.3626
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 304ms/step - accuracy: 0.8210 - loss: 0.4199 - val_accuracy: 0.8289 - val_loss: 0.4058
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 307ms/step - accuracy: 0.8276 - loss: 0.4376 - val_accuracy: 0.8316 - val_loss: 0.3759
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 304ms/step - accuracy: 0.8066 - loss: 0.4428 - val_accuracy: 0.8371 - val_loss: 0.3755
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.8184 - loss: 0.4056 - val_accuracy: 0.8466 - val_loss: 0.3734
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8174 - loss: 0.4058 - val_accuracy: 0.8507 - val_loss: 0.3651
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 309ms/step - accuracy: 0.8214 - loss: 0.4203 - val_accuracy: 0.8596 - val_loss: 0.3358
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 312ms/step - accuracy: 0.8206 - loss: 0.4068 - val_accuracy: 0.8466 - val_loss: 0.3702
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8252 - loss: 0.4133 - val_accuracy: 0.8534 - val_loss: 0.3496
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 441ms/step - accuracy: 0.8196 - loss: 0.4471 - val_accuracy: 0.8453 - val_loss: 0.3573
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 499ms/step - accuracy: 0.8014 - loss: 0.4413 - val_accuracy: 0.8364 - val_loss: 0.3703
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 486ms/step - accuracy: 0.8263 - loss: 0.4233 - val_accuracy: 0.8473 - val_loss: 0.3573
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 475ms/step - accuracy: 0.8271 - loss: 0.4114 - val_accuracy: 0.8187 - val_loss: 0.3810
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 18s 389ms/step - accuracy: 0.8152 - loss: 0.4088 - val_accuracy: 0.8664 - val_loss: 0.3283
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.8283 - loss: 0.4048 - val_accuracy: 0.8616 - val_loss: 0.3280
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.8397 - loss: 0.3664 - val_accuracy: 0.8200 - val_loss: 0.4002

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
model.save('model12.keras')

# %%
from keras.models import load_model

# Memuat model yang telah disimpan
model = load_model('model12.keras')

# Menampilkan ringkasan model untuk memastikan model berhasil dimuat
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ random_flip_3 (RandomFlip)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_rotation_3 (RandomRotation)   │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_zoom_3 (RandomZoom)           │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_contrast_3 (RandomContrast)   │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_brightness_3                  │ (None, 180, 180, 3)         │               0 │
# │ (RandomBrightness)                   │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ random_translation_3                 │ (None, 180, 180, 3)         │               0 │
# │ (RandomTranslation)                  │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gaussian_noise_3 (GaussianNoise)     │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 180, 180, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 180, 180, 16)        │             448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 90, 90, 16)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 90, 90, 32)          │           4,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 45, 45, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 45, 45, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 22, 22, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 22, 22, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 11, 11, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 15488)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 128)                 │       1,982,592 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,241,259 (23.81 MB)
#  Trainable params: 2,080,419 (7.94 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 4,160,840 (15.87 MB)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np
import matplotlib.pyplot as plt
# Ambil semua data uji untuk prediksi
y_true = []  # Label sebenarnya
y_pred = []  # Label prediksi

for images, labels in data_test:
    predictions = model.predict(images)
    predicted_classes = np.argmax(predictions, axis=1)
    y_true.extend(labels.numpy())
    y_pred.extend(predicted_classes)
# Buat confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=data_unggas)
disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
plt.title("Confusion Matrix")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step

# %%
# Evaluasi model pada data uji
test_loss, test_accuracy = model.evaluate(data_test)

print(f"Akurasi pada data uji: {test_accuracy * 100:.2f}%")
print(f"Loss pada data uji: {test_loss:.4f}")
# Out:
# C:\Users\TUF\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\nn.py:635: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.8307 - loss: 0.3948
# Akurasi pada data uji: 84.05%
# Loss pada data uji: 0.3792

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 10))

# Ambil satu batch dari data test
for images, labels in data_test.take(1):  
    predictions = model.predict(images)  # Prediksi batch gambar
    predicted_classes = np.argmax(predictions, axis=1)  # Ambil kelas prediksi
    predicted_probs = np.max(predictions, axis=1)  # Ambil probabilitas tertinggi untuk tiap prediksi

    for i in range(9):  # Tampilkan 9 gambar pertama
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype('uint8'))  # Tampilkan gambar
        pred_class = data_unggas[predicted_classes[i]]  # Kelas prediksi
        true_class = data_unggas[labels[i]]  # Kelas sebenarnya
        prob = predicted_probs[i] * 100  # Konversi probabilitas ke persen
        
        # Set judul dengan prediksi, probabilitas, dan kelas sebenarnya
        plt.title(f"Pred: {pred_class} ({prob:.2f}%)")
        plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
# Pada tahap selanjutnya kami mencoba melakukan beberapa kali pembelajaran dengan jumlah iterasi yang ber beda beda, berikut code dibawah

# %%
epochs_size = 30
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 485ms/step - accuracy: 0.8350 - loss: 0.3751 - val_accuracy: 0.8534 - val_loss: 0.3425
# Epoch 2/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 452ms/step - accuracy: 0.8374 - loss: 0.3519 - val_accuracy: 0.8718 - val_loss: 0.3114
# Epoch 3/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 24s 502ms/step - accuracy: 0.8504 - loss: 0.3482 - val_accuracy: 0.8712 - val_loss: 0.3058
# Epoch 4/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 482ms/step - accuracy: 0.8345 - loss: 0.3822 - val_accuracy: 0.8603 - val_loss: 0.3097
# Epoch 5/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 21s 467ms/step - accuracy: 0.8429 - loss: 0.3825 - val_accuracy: 0.8575 - val_loss: 0.3400
# Epoch 6/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 498ms/step - accuracy: 0.8402 - loss: 0.3839 - val_accuracy: 0.8746 - val_loss: 0.2990
# Epoch 7/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 474ms/step - accuracy: 0.8447 - loss: 0.3664 - val_accuracy: 0.8712 - val_loss: 0.3139
# Epoch 8/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 22s 468ms/step - accuracy: 0.8480 - loss: 0.3511 - val_accuracy: 0.8125 - val_loss: 0.4193
# Epoch 9/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 23s 490ms/step - accuracy: 0.8472 - loss: 0.3675 - val_accuracy: 0.8657 - val_loss: 0.3128
# Epoch 10/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 342ms/step - accuracy: 0.8369 - loss: 0.3639 - val_accuracy: 0.8337 - val_loss: 0.3551
# Epoch 11/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.8351 - loss: 0.3609 - val_accuracy: 0.8609 - val_loss: 0.3401
# Epoch 12/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.8491 - loss: 0.3697 - val_accuracy: 0.8507 - val_loss: 0.3569
# Epoch 13/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.8442 - loss: 0.3997 - val_accuracy: 0.8453 - val_loss: 0.3422
# Epoch 14/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 303ms/step - accuracy: 0.8437 - loss: 0.3773 - val_accuracy: 0.8323 - val_loss: 0.3896
# Epoch 15/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.8414 - loss: 0.3819 - val_accuracy: 0.8541 - val_loss: 0.3065
# Epoch 16/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 297ms/step - accuracy: 0.8448 - loss: 0.3627 - val_accuracy: 0.8616 - val_loss: 0.3058
# Epoch 17/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 306ms/step - accuracy: 0.8473 - loss: 0.3682 - val_accuracy: 0.8582 - val_loss: 0.3168
# Epoch 18/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.8513 - loss: 0.3299 - val_accuracy: 0.8446 - val_loss: 0.3525
# Epoch 19/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.8524 - loss: 0.3294 - val_accuracy: 0.8514 - val_loss: 0.3246
# Epoch 20/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 324ms/step - accuracy: 0.8607 - loss: 0.3253 - val_accuracy: 0.8344 - val_loss: 0.3887
# Epoch 21/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8338 - loss: 0.4308 - val_accuracy: 0.8814 - val_loss: 0.2859
# Epoch 22/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.8546 - loss: 0.3421 - val_accuracy: 0.8712 - val_loss: 0.2819
# Epoch 23/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 328ms/step - accuracy: 0.8618 - loss: 0.3508 - val_accuracy: 0.8500 - val_loss: 0.3225
# Epoch 24/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 319ms/step - accuracy: 0.8585 - loss: 0.3475 - val_accuracy: 0.8800 - val_loss: 0.2795
# Epoch 25/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.8651 - loss: 0.3173 - val_accuracy: 0.8459 - val_loss: 0.3668
# Epoch 26/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.8399 - loss: 0.3723 - val_accuracy: 0.8732 - val_loss: 0.3081
# Epoch 27/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 310ms/step - accuracy: 0.8582 - loss: 0.3219 - val_accuracy: 0.8712 - val_loss: 0.3019
# Epoch 28/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.8509 - loss: 0.3283 - val_accuracy: 0.8569 - val_loss: 0.3157
# Epoch 29/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 311ms/step - accuracy: 0.8520 - loss: 0.3606 - val_accuracy: 0.8814 - val_loss: 0.2781
# Epoch 30/30
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 308ms/step - accuracy: 0.8554 - loss: 0.3385 - val_accuracy: 0.8582 - val_loss: 0.3022

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
epochs_size = 10
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.8528 - loss: 0.3357 - val_accuracy: 0.8896 - val_loss: 0.2842
# Epoch 2/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 325ms/step - accuracy: 0.8389 - loss: 0.3718 - val_accuracy: 0.8759 - val_loss: 0.2804
# Epoch 3/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.8530 - loss: 0.3363 - val_accuracy: 0.8500 - val_loss: 0.3203
# Epoch 4/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 331ms/step - accuracy: 0.8636 - loss: 0.3035 - val_accuracy: 0.8603 - val_loss: 0.3206
# Epoch 5/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.8573 - loss: 0.3463 - val_accuracy: 0.8507 - val_loss: 0.3350
# Epoch 6/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.8488 - loss: 0.3507 - val_accuracy: 0.8657 - val_loss: 0.3028
# Epoch 7/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.8819 - loss: 0.3136 - val_accuracy: 0.8678 - val_loss: 0.3155
# Epoch 8/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 334ms/step - accuracy: 0.8646 - loss: 0.3367 - val_accuracy: 0.8262 - val_loss: 0.4148
# Epoch 9/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.8542 - loss: 0.3540 - val_accuracy: 0.8357 - val_loss: 0.4029
# Epoch 10/10
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8490 - loss: 0.3618 - val_accuracy: 0.8650 - val_loss: 0.2977

# %%
epochs_range = range(epochs_size)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range, history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range, history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
epochs_size = 50
history = model.fit(data_train, validation_data=data_val, epochs=epochs_size)
# Out:
# Epoch 1/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 324ms/step - accuracy: 0.8600 - loss: 0.3322 - val_accuracy: 0.8678 - val_loss: 0.3006
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 309ms/step - accuracy: 0.8837 - loss: 0.2949 - val_accuracy: 0.8664 - val_loss: 0.3514
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.8590 - loss: 0.3357 - val_accuracy: 0.8623 - val_loss: 0.3069
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 306ms/step - accuracy: 0.8731 - loss: 0.2987 - val_accuracy: 0.8800 - val_loss: 0.2863
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 317ms/step - accuracy: 0.8552 - loss: 0.3162 - val_accuracy: 0.8609 - val_loss: 0.3200
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 315ms/step - accuracy: 0.8363 - loss: 0.3806 - val_accuracy: 0.8432 - val_loss: 0.3355
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - accuracy: 0.8724 - loss: 0.3333 - val_accuracy: 0.8773 - val_loss: 0.3069
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.8581 - loss: 0.3060 - val_accuracy: 0.8957 - val_loss: 0.2544
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.8899 - loss: 0.2798 - val_accuracy: 0.8923 - val_loss: 0.2587
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 307ms/step - accuracy: 0.8711 - loss: 0.3131 - val_accuracy: 0.8773 - val_loss: 0.2800
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 301ms/step - accuracy: 0.8718 - loss: 0.3115 - val_accuracy: 0.8698 - val_loss: 0.2920
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 306ms/step - accuracy: 0.8861 - loss: 0.2864 - val_accuracy: 0.8957 - val_loss: 0.2618
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 322ms/step - accuracy: 0.8775 - loss: 0.2960 - val_accuracy: 0.8521 - val_loss: 0.4138
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 310ms/step - accuracy: 0.8700 - loss: 0.2969 - val_accuracy: 0.8848 - val_loss: 0.2817
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 317ms/step - accuracy: 0.8814 - loss: 0.2627 - val_accuracy: 0.8807 - val_loss: 0.2947
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8853 - loss: 0.2939 - val_accuracy: 0.8596 - val_loss: 0.3261
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.8878 - loss: 0.2646 - val_accuracy: 0.8494 - val_loss: 0.3262
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8752 - loss: 0.2834 - val_accuracy: 0.8712 - val_loss: 0.2994
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 313ms/step - accuracy: 0.8631 - loss: 0.3471 - val_accuracy: 0.8793 - val_loss: 0.2902
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 308ms/step - accuracy: 0.8775 - loss: 0.2813 - val_accuracy: 0.8834 - val_loss: 0.2822
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 320ms/step - accuracy: 0.8627 - loss: 0.3207 - val_accuracy: 0.8841 - val_loss: 0.2630
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8762 - loss: 0.3056 - val_accuracy: 0.8814 - val_loss: 0.2860
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8795 - loss: 0.2867 - val_accuracy: 0.8712 - val_loss: 0.3289
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 327ms/step - accuracy: 0.8825 - loss: 0.2758 - val_accuracy: 0.8705 - val_loss: 0.3216
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8839 - loss: 0.2936 - val_accuracy: 0.8630 - val_loss: 0.2802
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.8525 - loss: 0.3149 - val_accuracy: 0.8821 - val_loss: 0.2566
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 316ms/step - accuracy: 0.8788 - loss: 0.3028 - val_accuracy: 0.8909 - val_loss: 0.2610
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 314ms/step - accuracy: 0.8696 - loss: 0.2970 - val_accuracy: 0.8739 - val_loss: 0.2673
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 312ms/step - accuracy: 0.8768 - loss: 0.2885 - val_accuracy: 0.8596 - val_loss: 0.3521
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 360ms/step - accuracy: 0.8856 - loss: 0.2611 - val_accuracy: 0.8793 - val_loss: 0.2771
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8915 - loss: 0.2572 - val_accuracy: 0.8569 - val_loss: 0.3350
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8802 - loss: 0.3014 - val_accuracy: 0.8875 - val_loss: 0.2415
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.8861 - loss: 0.2753 - val_accuracy: 0.8909 - val_loss: 0.2555
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8871 - loss: 0.2721 - val_accuracy: 0.9046 - val_loss: 0.2311
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 321ms/step - accuracy: 0.8741 - loss: 0.2968 - val_accuracy: 0.8930 - val_loss: 0.2557
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.8600 - loss: 0.3162 - val_accuracy: 0.8909 - val_loss: 0.2456
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 329ms/step - accuracy: 0.8835 - loss: 0.2807 - val_accuracy: 0.8882 - val_loss: 0.2472
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 324ms/step - accuracy: 0.8780 - loss: 0.3093 - val_accuracy: 0.9039 - val_loss: 0.2284
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 334ms/step - accuracy: 0.8854 - loss: 0.2984 - val_accuracy: 0.8984 - val_loss: 0.2433
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.8889 - loss: 0.2884 - val_accuracy: 0.8971 - val_loss: 0.2673
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 330ms/step - accuracy: 0.9035 - loss: 0.2774 - val_accuracy: 0.8943 - val_loss: 0.2506
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 16s 346ms/step - accuracy: 0.8836 - loss: 0.2726 - val_accuracy: 0.8828 - val_loss: 0.2690
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 326ms/step - accuracy: 0.8849 - loss: 0.2781 - val_accuracy: 0.9005 - val_loss: 0.2589
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 323ms/step - accuracy: 0.8767 - loss: 0.2944 - val_accuracy: 0.9039 - val_loss: 0.2502
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 305ms/step - accuracy: 0.8879 - loss: 0.2911 - val_accuracy: 0.8937 - val_loss: 0.2710
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 15s 318ms/step - accuracy: 0.8873 - loss: 0.2787 - val_accuracy: 0.9059 - val_loss: 0.2227
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 312ms/step - accuracy: 0.8765 - loss: 0.2764 - val_accuracy: 0.8868 - val_loss: 0.2599
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 14s 306ms/step - accuracy: 0.8896 - loss: 0.2671 - val_accuracy: 0.9148 - val_loss: 0.2091
# Epoch 49/50
#  5/46 ━━━━━━━━━━━━━━━━━━━━ 9s 238ms/step - accuracy: 0.8797 - loss: 0.2633
